# %% [markdown]
# # APPROXIMATE SOLUTION OF THE SCHRÖDINGER EQUATION FOR A DOUBLE SQUARE WELL POTENTIAL - ASSIGNMENT (STUDENT HANDOUT)  #

# %% [markdown]
# # Background information and assignment description

# %% [markdown]
# ## General approach to applying the linear variation method

# %% [markdown]
# To obtain approximate solutions to the time-indpendent Schrödinger equation within the framework of the linear variation method, one can follow the following steps.
#
# 1. Select a basis set $\{\phi_n\}$ and determine the number of basis functions ($N$) to include in the calculation.
#    - The basis functions should obey the appropriate boundary conditions
#    - Although the basis functions do not necessarily have to be orthonormal, it helps when they are.
# \begin{equation}
# \int_\text{all space} \phi_n^*  \phi_m {\rm d}\tau = \delta_{m,n}
# \end{equation}
# where the Krönecker delta function $\delta_{m,n}$ is defined as
#
# \begin{equation}
# \delta_{n,m}= \begin{cases}
#  0 \hspace{2.0cm} n \neq  m\\
#  \\
#  1 \hspace{2cm} n = m\\
# \end{cases}.
# \end{equation}
#
# <br>
#
# 2. Calculate the matrix representation of Hamiltonian (an $N\times N$ matrix)
# \begin{equation}
# \bf H = T + V \tag{3.1}
# \end{equation}
# In the case of an orthonormal basis, the matrix form of the time-independent Schrödinger equation is ${\bf Hc} = E {\bf c}$.
#    - Since the Hamiltonian is the sum of the kinetic ($\hat{T}$) and potential ($\hat{V}$) energy operators, computing the matrix representation the kinetic ($\bf T$) and potential ($\bf V$) energy matrices separately helps organize and debug your code.
#    - The kinetic energy matrix elements are given by
# \begin{equation}
# T_{n,m} = \int_\text{ all space} \phi_n^* \hat{T} \phi_m {\rm d}\tau
# \tag{3.2}
# \end{equation}
#    - The potential energy matrix elements are given by
# \begin{equation}
# V_{n,m} = \int_\text{all space} \phi_n^* \hat{V} \phi_m {\rm d}\tau
# \tag{3.3}
# \end{equation}
#    - Depending on the operator and the basis set, these integrals may be simplified. If they cannot, one can (hopefully) use some numerical integration and/or differentiation technique.
#
# <br>
#
# 3. Diagonalize the Hamiltonian to obtain the eigenvalues (approximate energies) and eigenvectors (expansion coefficients). There will be $N$ eigenvalues $\{ E^{(n)}\}$ and $N$ eigenvectors $\{ {\bf c}^{(n)}\}$ (column vectors). Generally, the eigenvectors after diagonalization are orthonormal
#
# \begin{equation}
# \left({\bf c}^{(n)}\right)^T \cdot {\bf c}^{(m)} = \delta_{m,n}
# \end{equation}
#
# 4. Using the expansion coefficients, the approximate wave function $\psi^{(n)}$ corresponding to eigenvalue $E^{(n)}$
# \begin{equation}
# \psi^{(n)} = \sum_{i=1}^{N} c_i^{(n)} \phi_i
# \end{equation}
# can be used to calculate properties of the system.

# %% [markdown]
# ## <span style="color:blue"> Assignment </span>

# %% [markdown]
# <span style="color:blue">
#
# Consider a particle with mass $M$ that moves along $x$ experiences the potential
# \begin{equation}
# V(x) = \begin{cases}
#  V_1 \hspace{2.1cm} 0 \leq x \leq W_1 \\
#  \\
#  V_B \hspace{2cm} W_1 \leq x \leq W_1 + W_B \\
#  \\
#  0 \hspace{2cm} W_1 + W_B \leq x \leq L \\
#  \\
#  \infty \hspace{2cm} \text{everywhere else}
# \end{cases}
# \end{equation}
# where $V_B \geq V_1 \geq 0$. For a visualization of the potential, see the image below.
#
# <img src="https://github.com/act-cms/lesson-02-linear-variation-method/blob/main/potential_double_well.jpg?raw=true" style="display: block; margin: 0 auto; max-height:200px;">
#
#
# Using the orthonormal particle in  1-D box eigenfunctions
# \begin{equation}
# \phi_n(x) = \sqrt{\frac{2}{L}} {\rm sin}\left( \frac{n\pi x}{L}\right) \hspace{1cm} n = 1,2, ...
# \end{equation}
#
#
# **Write code that**
# 1. builds the kinetic energy matrix (see Eq. 3.2 and pre-lab exercise 4)
# 2. builds the potential energy matrix (see Eq. 3.3 and pre-lab exercise 7)
# 3. builds the Hamiltonian from the kinetic and potential energy matrices (see equation 3.1)
# 4. calculates the approximate solutions (energies and expansion coefficients) of the time-independent Schrödinger equation by diagonalizing the Hamiltonian (see [section 4](#matrix-diagonalization-in-python))
# 5. calculates the value of the ground-state wave function at some value of $x$ (see section 12 of the ["Introduction to programming and Python"](https://github.com/act-cms/lesson-01-introduction-to-programming-and-python) exercises)
# 6. plots the ground-state wave function for $0 \leq x \leq L$ (see section 12 of the ["Introduction to programming and Python"](https://github.com/act-cms/lesson-01-introduction-to-programming-and-python) exercises)
# 7. calculates the total probability $P(x_{min}\leq x\leq x_{max})$ that the particle is found in the region $x_{min} \leq x \leq x_{max}$ assuming that the particle is in the ground state. (see section 13 of the ["Introduction to programming and Python"](https://github.com/act-cms/lesson-01-introduction-to-programming-and-python) exercises)
# 8. prints user-defined input parameters and key results including
#    > - the input parameters ($N$, $W$s, $V$s, etc ...)
#    > - ground-state energy
#    > - $P(0 \leq x \leq W_1)$
#    > - $P(W_1 \leq x \leq W_1 + W_B)$
#    > - $P(W_1 + W_B \leq x \leq L)$
#
# **In your algorithm**,
#
# - keep $M$, $W_1$, $W_B$, $L$, $M$, $V_1$, $V_B$, and $N$ (the number of basis vectors in the linear expansion) as input variables that can be specified by the user
# - assume that the user will input lengths in units of  ${\mathring{\rm{A}}}$, potentials in units of eV, and masses in units of kg
# - use atomic units
# - to simplify debugging and to increase readability of your code, use functions as appropriate
#
# **Then, use your code to complete the following**
# </span>
#
# <span style="color:blue">
# 1. Using the following parameters: $M=m_e$, $V_1 = 0$, $V_B=10$ eV, $W_1 = W_B=1.0$ ${\mathring{\rm{A}}}$, and $L=3.0$ ${\mathring{\rm{A}}}$, calculate the ground-state energy for $N=2, 5, 10, 20, 30, 40, 50, 100$. Include your results (keep 5 significant figures) in the Markdown table below.
# </span>span>
#
#    | $N$   | $E$(eV) |
#    |-------|-----------|
#    |    2  |   ???     |
#    |    5  |   ???     |
#    |   10  |   ???     |
#    |   20  |   ???     |
#    |   30  |   ???     |
#    |   40  |   ???     |
#    |   50  |   ???     |
#    |  100  |   ???     |
#
#
# <span style="color:blue">
# 2. Using the following parameters: $M=m_e$, $V_1 = 0$, $V_B=50$ eV, $W_1 = W_B=1.0$ ${\mathring{\rm{A}}}$, and $L=3.0$ ${\mathring{\rm{A}}}$, calculate the ground-state energy for $N=2, 5, 10, 20, 30, 40, 50, 100$. Include your results (keep 5 significant figures) in Table 1 below.
# </span>
#
#    | $N$   | $E$(eV) |
#    |-------|-----------|
#    |    2  |   ???     |
#    |    5  |   ???     |
#    |   10  |   ???     |
#    |   20  |   ???     |
#    |   30  |   ???     |
#    |   40  |   ???     |
#    |   50  |   ???     |
#    |  100  |   ???     |
#
# <span style="color:blue">
# 3. Looking at your results in Table 1, discuss the convergence properties of the linear variation method. For example, is the convergence of the energy monotonic or oscillatory? How many basis functions are required to converge the energy with 1 meV accuracy?
# </span>
#
# ENTER YOUR WRITTEN RESPONSE HERE BY DOUBLE-CLICKING ON THE CELL AND REPLACING THIS TEXT
# <br>
#
# <span style="color:blue">
# 4. Looking at your results in Tables 1 and 2, how is the convergence of the linear variation method affected by the barrier height $V_B$?
# </span>
#
# ENTER YOUR WRITTEN RESPONSE HERE BY DOUBLE-CLICKING ON THE CELL AND REPLACING THIS TEXT
# <br>
#
# <span style="color:blue">
# 5. Using the following parameters: $V_1 = V_B= 25$ eV, $W_1 = W_B=1.0$ ${\mathring{\rm{A}}}$, $L=3.0$ ${\mathring{\rm{A}}}$, and $N=100$, calculate $P(0 \leq x \leq W_1+W_B)$ for an electron ($M=m_e$) and then a proton ($M=m_p$). Enter your results into the table below. Based on your results, what can you say about the relationship between the mass of a particle and the total probability the particle permeates the classically forbidden region?
# </span>
#
#    | $m$   | $P(0 \leq x \leq W_1+W_B)$ |
#    |-------|-----------|
#    |    $m_e$  |  ???     |
#    |    $m_p$  |  ???     |
#
# ENTER YOUR WRITTEN RESPONSE HERE BY DOUBLE-CLICKING ON THE CELL AND REPLACING THIS TEXT
#
# <span style="color:blue">
# 6. Using the following parameters: $V_1 = 5$ eV, $V_B= 50$ eV, $W_1 = W_B=1.0$ ${\mathring{\rm{A}}}$, $L=3.0$ ${\mathring{\rm{A}}}$, and $N=100$, calculate $P(0 \leq x \leq W_1)$ and $P(W_1 \leq x \leq W_1+W_B)$ for an electron ($M=m_e$). Enter your results into the table below. Based on the form of the potential, do your results make physical sense?
# </span>
#
#  | region | $P$ |
#  |--------|-----|
#  | $0 \leq x \leq W_1$     | ??? |
#  | $W_1+W_B \leq x \leq L$ | ??? |
#
# ENTER YOUR WRITTEN RESPONSE HERE BY DOUBLE-CLICKING ON THE CELL AND REPLACING THIS TEXT
# <br>

# %% [markdown]
# # Python code development

# %% [markdown]
# ## Load libraries

# %% [markdown]
# This is where you should include the appropriate code to load the relevant Python libraries

# %% [markdown]
# ## Define input variables

# %% [markdown]
# This is where you would assign values to variables that can be adjusted by the end-user (e.g. particle mass, barrier width, barrier height, etc.) <br>
# I suggest that you use use __descriptive variable names__ that are __not too onerous__ to type.

# %% [markdown]
# ## Define functions

# %% [markdown]
# In this section, you will add as many dropdown cells as needed to implement the functions that are going to be used in the code.
#
# __NOTE:__ To aid in reading and debugging your code, use a separate cell for each function! Lastly, to aid the end-user, make sure to include comments and documentation in the form of DocStrings for your functions. For a refresher on how to use DocStrings, see section 8 of the ["Introduction to programming and Python"](https://github.com/act-cms/lesson-01-introduction-to-programming-and-python) exercises.

# %%
# if needed, write code for a function here

# %%
# if needed, write code for a function here

# %%
# if needed, write code for a function here

# %%
# if needed, write code for a function here

# %%
# if needed, write code for a function here

# %%
# if needed, write code for a function here

# %%
# if needed, write code for a function here

# %%
# if needed, write code for a function here

# %%
# if needed, write code for a function here

# %% [markdown]
# ## Initialize arrays and matrices

# %% [markdown]
# This is where you would initialize any arrays and matrices that you will use in the code below.

# %% [markdown]
# ## Convert parameter values to atomic units

# %% [markdown]
# If needed, this is where you would convert input values to atomic units.

# %% [markdown]
# ## Calculate the kinetic energy, potential energy, and finally, the Hamiltonian matrices

# %% [markdown]
# This is where you would implement the code to call the appropriate functions to calculate **T**, **V**, and **H**. For the general expressions, see the [background information](#general-approach-to-applying-the-linear-variation-method).

# %% [markdown]
# ## DIagonalize the Hamiltonian to calculate the approximate solutions to the Schrödinger equation

# %% [markdown]
# This is where you would call the reelvant linear algebra functions to diagonalzie the Hamiltonian.

# %% [markdown]
# ## Print key results

# %% [markdown]
# This is where you would communicate the key results of the calculations as outlined in the [Assignment](#assignment) section of this notebook. To refresh your memory on how to print formatted output using f-string printing, see section 7 of the ["Introduction to programming and Python"](https://github.com/act-cms/lesson-01-introduction-to-programming-and-python) exercises.
